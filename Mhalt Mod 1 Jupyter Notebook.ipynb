# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 5
b = 13
a*b
# Out:
# 65

# %%
a/b
# Out:
# 0.38461538461538464

# %%
import pandas
import numpy
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([7,12,45], [2,10,33])

# %%
plt.scatter([3,16,41], [1,21,53])
